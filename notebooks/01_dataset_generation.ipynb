# %%
import pandas as pd
import numpy as np
import random
from datetime import datetime, timedelta

# %%
products = {
    "Parmigiano Reggiano": "Cheese",
    "Pecorino Romano": "Cheese",
    "Prosciutto Crudo": "Cured Meat",
    "Salame Napoli": "Cured Meat",
    "Chianti Classico": "Wine",
    "Nero d'Avola": "Wine",
    "Fresh Pasta": "Pasta",
    "Truffle Pasta": "Pasta",
    "Extra Virgin Olive Oil": "Olive Oil",
    "Garlic Bread": "Bakery",
    "Fig Jam": "Preserves"
}

# %%
payment_methods = [
    "Credit Card",
    "Cash",
    "PayPal",
    "Debit Card"
]
